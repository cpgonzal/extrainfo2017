# %% [markdown]
# <h2> Lab: Análisis de los gastos en tarjetas black de Bankia </h2>
# <img align=left src="images/tarjetas-black.jpg" width=200 height=200 />
# </a>

# %%
from pyspark import SparkContext, SQLContext
import pandas as pd
sc =SparkContext()

# %% [markdown]
# ### Question 1
#
# Load data in fraude/movimientos_tarjetas_black_caja_madrid.csv

# %%
sqlContext = SQLContext(sc)

def answer_one():
    df = sqlContext.read.format('com.databricks.spark.csv') \
                    .options(header='true', inferschema='true', delimiter=';') \
                    .load('file:///home/jovyan/work/extrainfo2017/tema04/fraude/movimientos_tarjetas_black_caja_madrid.csv')
    return df

df=answer_one() 
df.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- nombre: string (nullable = true)
#  |-- importe: double (nullable = true)
#  |-- nombre_comercio: string (nullable = true)
#  |-- actividad: string (nullable = true)
#  |-- operacion: string (nullable = true)
#  |-- fecha: timestamp (nullable = true)
#  |-- fechayear: integer (nullable = true)
#  |-- fechamonth: integer (nullable = true)
#  |-- fechaday-of-month: integer (nullable = true)
#  |-- fechaday-of-week: integer (nullable = true)
#  |-- hora: string (nullable = true)
#  |-- horahour: integer (nullable = true)
#  |-- horaminute: integer (nullable = true)
#  |-- horasecond: integer (nullable = true)

# %% [markdown]
# ### Question 2
#
# Map each person with his expenses using the map function
#
# Hint: Convert the data frame loaded previously to RDD using <data_rdd>=<data_frame>.rdd

# %%
def answer_two():
    return None

expenses=answer_two() 
expenses
# Out:
#                            name  expense
# 0          ABEJAS JUÁREZ, PABLO   400.18
# 1          ABEJAS JUÁREZ, PABLO   428.86
# 2          ABEJAS JUÁREZ, PABLO   130.65
# 3          ABEJAS JUÁREZ, PABLO    67.25
# 4          ABEJAS JUÁREZ, PABLO     1.70
# 5          ABEJAS JUÁREZ, PABLO     0.70
# 6          ABEJAS JUÁREZ, PABLO    92.20
# 7          ABEJAS JUÁREZ, PABLO   300.00
# 8          ABEJAS JUÁREZ, PABLO    32.90
# 9          ABEJAS JUÁREZ, PABLO    60.40
# 10         ABEJAS JUÁREZ, PABLO     5.30
# 11         ABEJAS JUÁREZ, PABLO    64.37
# 12         ABEJAS JUÁREZ, PABLO   154.70
# 13         ABEJAS JUÁREZ, PABLO   373.26
# 14         ABEJAS JUÁREZ, PABLO   459.03
# 15         ABEJAS JUÁREZ, PABLO     5.10
# 16         ABEJAS JUÁREZ, PABLO     1.70
# 17         ABEJAS JUÁREZ, PABLO    18.00
# 18         ABEJAS JUÁREZ, PABLO    40.00
# 19         ABEJAS JUÁREZ, PABLO    62.00
# 20         ABEJAS JUÁREZ, PABLO     5.30
# 21         ABEJAS JUÁREZ, PABLO     0.85
# 22         ABEJAS JUÁREZ, PABLO     2.55
# 23         ABEJAS JUÁREZ, PABLO    21.00
# 24         ABEJAS JUÁREZ, PABLO    10.00
# 25         ABEJAS JUÁREZ, PABLO     0.70
# 8                 RATO FIGAREDO, RODRIGO DE       2305.16
# 9                         AMAT ROCA, MATÍAS       1676.93
# 10          RODRIGUEZ GONZÁLEZ, MANUEL JOSÉ       1661.00
# 11    RODRÍGUEZ-PONGA SALAMANCA, ESTANISLAO       1547.20
# 12  GÓMEZ DEL PULGAR PERALES, ÁNGEL EUGENIO       1517.11
# 13       DE LA MERCED MONGE, MARÍA MERCEDES       1453.11
# 14                  MARTÍNEZ VILCHES, RAMÓN       1252.74
# 15            ASTORQUI PORTERA, JUAN MANUEL       1251.65
# 16                    PEDROCHE NIETO, JESÚS       1249.96
# 17          SÁNCHEZ CARLOS, SANTIAGO JAVIER       1122.75
# 18               IRANZO MARTÍN, JUAN EMILIO       1073.75
# 19         CAFRANGA CAVESTANY, MARÍA CARMEN        897.90
# 20             ARAUJO SERRANO, MIGUEL ÁNGEL        709.70
# 21      PRADILLO MORENO DE LA SANTA, RAFAEL        663.45
# 22                     ABEJAS JUÁREZ, PABLO        498.09
# 23                COUCEIRO OJEDA, ALEJANDRO        475.30
# 24   REY DE VIÑAS SÁNCHEZ-MAJESTAD, ANTONIO        452.90
# 25                      GÓMEZ MORENO, JORGE        370.85
# 26                   CORSINI FREESE, MIGUEL        361.60
# 27    ROMERO DE TEJADA Y PICATOSTE, RICARDO        350.00
# 28                  CERÓN ESCUDERO, CÁNDIDO        277.00
# 29               GUTIÉRREZ MOLINER, BELTRÁN        269.50
# 30                   ESPINAR GALLEGO, RAMÓN        247.87
# 31                        CRUZ ORIVE, RUBÉN        246.65
# 32                    FERRAZ RICARTE, RAMÓN        245.00
# 33                MIGUEL SÁNCHEZ, JAVIER DE        229.60
# 34           FERNÁNDEZ ÁLVAREZ, ARTURO LUIS        195.00
# 35                  CÁMARA EGUINOA, ANTONIO        190.81
# 36              RIVA ÁMEZ, JOSÉ MARÍA DE LA        188.05
# 37             CONTRERAS GÓMEZ, JOSÉ CARLOS        145.00
# 38            FERNÁNDEZ YRUEGAS MORO, DARÍO        128.00
# 39                  SERRANO ANTÓN, FERNANDO         71.20
# 40                 ZAPATERO GÓMEZ, VIRGILIO         67.83
# 41                  ARTETA VICO, JOSÉ MARÍA         64.30
# 42                     BUGIDOS GARAY, PEDRO         52.00
# 43                   GARCÍA PONTES, JOAQUÍN         46.80
# 44             ÁLVAREZ GAYOL, MARÍA ENEDINA         45.00
# 45          RÍO GARCÍA DE SOLA, IGNACIO DEL         29.10
# 46                BLESA DE LA PARRA, MIGUEL         24.00

# %% [markdown]
# ### Question 6
#
# Using pandas, represent in a chart the evolution for years in the expenses of Rodrigo Rato

# %%
print None
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Question 7
#
# Using pandas, represent the top 5 activities of the business where R. Rato wasted much more

# %%
print None
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# ### Question 8
#
# Using pandas, represent in a chart the top 5 people that wasted much more

# %%
print None
# Out:
# <img src="data:image/png;base64,...">
